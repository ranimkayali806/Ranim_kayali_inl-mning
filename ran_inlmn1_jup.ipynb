# %% [markdown]
# # Uppgift 1
#
# X-2Y+2Z = 3 </br>
# -X+Y+Z=4     </br>
# 2X+2Y-3Z=-3   </br>

# %%
a = [1,-2,2,3]
b =[-1,1,1,4]
c=[2,2,-3,-3]

# %%
RRRR

# %%
for i in range(len(a)):
    a[i] = a[i]
    b[i] = b[i]+ a[i]
    c[i] =c[i]-2*a[i]

# %%
a
# Out:
# [1, -2, 2, 3]

# %%
b
# Out:
# [0, -1, 3, 7]

# %%
for i in range(len(a)):
    a[i] = a[i]
    b[i] = b[i]
    c[i] = c[i]+ 6*b[i]

# %%
a
# Out:
# [1, -2, 2, 3]

# %%
b
# Out:
# [0, -1, 3, 7]

# %%
c
# Out:
# [0, 0, 11, 33]

# %% [markdown]
# Z=3

# %% [markdown]
# X=1

# %% [markdown]
# Y=2

# %% [markdown]
# # uppgift 2
# P=[0,0] </br>
# Q=[2,3]  </br>
# R=[8,8]   </br>

# %%
import matplotlib.pyplot as plt

# %%
P=[0,0]
Q=[2,3]
R=[8,8]

# %%
plt.plot([P[0], Q[0]], [P[1], Q[1]])

# %%
plt.plot([Q[0], R[0]], [Q[1], R[1]])

# %%
plt.plot([P[0], Q[0]], [P[1], Q[1]])
plt.plot([Q[0], R[0]], [Q[1], R[1]])

# %% [markdown]
# # UPPGIFT  3

# %%
U=[1,2,3]
V=[2,2,2]

# %% [markdown]
# U+V

# %%
result=[0,0,0]

# %%
for i in range(len(U)):
    result[i]= U[i]+V[i]
print(result)
# Out:
# [3, 4, 5]

# %%
W=[1,0,1,0,1]
X=[5,6,6,5,9]

# %% [markdown]
# W+X

# %%
result=[[0],[0],[0],[0],[0]]

# %%
for i in range(len(W)):
    result[i]=W[i]+X[i]
    
print(result)
# Out:
# [6, 6, 7, 5, 10]

# %% [markdown]
# # uppgift 4

# %%
import math

# %%
U=[0,2,3]

# %%
U
# Out:
# [0, 2, 3]

# %%
V=[0,4,6]

# %%
V
# Out:
# [0, 4, 6]

# %% [markdown]
# U.V

# %%
result=sqrt((0**2+2**2+3**2)) * sqrt((0**2+4**2+6**2))

print(result)
# Out:
# 25.999999999999996

# %% [markdown]
# # uppgift 5

# %%
A =[[1,2], [3,2]]
B= [[4,5],[6,5]]

# %%
A
# Out:
# [[1, 2], [3, 2]]

# %%
B
# Out:
# [[4, 5], [6, 5]]

# %% [markdown]
# A+B

# %%
result=[[0,0],[0,0]]

# %%
for i in range(len(A)):
    for j in range(len(A[0])):
        
        result[i][j]=A[i][j]+B[i][j]

print(result)
# Out:
# [[5, 7], [9, 7]]

# %% [markdown]
# # uppgift 6

# %%
A=[[1,2],[3,2],[1,3]]

# %%
B=[[4,5,6],[6,5,4]]

# %%
result=[[0,0,0],[0,0,0],[0,0,0]]

# %% [markdown]
# A*B

# %%
for i in range(len(A)):
    for j in range(len(B[0])):
        for k in range(len(B)):
            result[i][j] +=A[i][k]*B[k][j]
print(result)
# Out:
# [[16, 15, 14], [24, 25, 26], [22, 20, 18]]
